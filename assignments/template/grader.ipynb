# %%
import pandas as pd
import numpy as np
import os
import ast

# %%
rubrics = ['public_rubric.xls', 'private_rubric.xls']
target = 'assignment_0'

# %%
os.system(f'ipython nbconvert --to python {target}.ipynb');

# %%
exec(f'import {target} as submission')

# %%
def from_str(s):
    try:
        if s is np.nan:
            return ''
    except:
        pass
    
    try:
        if s is None:
            return ''
    except:
        pass
    
    try:
        if len(s) == 0:
            return ''
    except:
        pass
    
    try:
        return ast.literal_eval(s)
    except:
        return s

# %%
def grade(x, rubric):
    if type(rubric) == list:
        passed = []
        failed = []
        for r in rubric:
            next_passed, next_failed = grade(x, r)
            passed.append(next_passed)
            failed.append(next_failed)
        return passed, failed
    
    r = pd.read_excel(rubric, header=0)
    
    passed = []
    failed = []
    
    for i in range(r.shape[0]):
        next_test = {}
        next_test['cmd'] = f"x.{r.loc[i]['function']}({str(from_str(r.loc[i]['input']))})"
        next_test['target'] = from_str(r.loc[i]['solution'])
        next_test['points'] = float(r.loc[i]['points'])
        next_test['rubric'] = rubric
        
        #FIXME: this part is broken...
        try:
            next_test['response'] = eval(next_test['cmd'])
            print('got here')
        except:
            next_test['response'] = None
        
        try:            
            if response == next_test['target']:
                passed.append(next_test)
            else:
                failed.append(next_test)
        except:
            try:
                if np.isnan(next_test['target']):
                    passed.append(next_test)
                else:
                    failed.append(next_test)
            except:
                failed.append(next_test)
    
    return passed, failed

# %%
def report(passed, failed):
    possible = 0
    earned = 0
    
    def summarize(description, cases):
        if len(cases) == 0:
            return f'No cases {description}ed.'
        
        summary = [f'The following test cases {(description + "ed").upper()}:']
        for i, c in enumerate(cases):
            summary.append(f"TEST {i+1}. Command: {cases['cmd']}")
            summary.append(f"\t Observed output: {cases['response']}")
            summary.append(f"\t Expected output: {cases['target']}")            
            summary.append('')
    
        return '\n'.join(summary[:-1])
    
    for p in passed:
        earned += p['points']
        possible += p['points']
    
    for f in failed:
        possible += f['points']
    
    print('Total points earned: {earned}/{possible} = {100 * float(earned)/(float(possible))}%')
    print('\nDetails:\n')
    print(summarize('pass', passed))
    print('\n')
    print(summarize('fail', failed))

# %%
#STOPPED  HERE: not quite working...

# %%
passed, failed = grade(submission, rubrics)
# Out:
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here

# %%
failed
# Out:
# [[{'cmd': 'x.say_hello()',
#    'target': 'hello',
#    'points': 0.5,
#    'rubric': 'public_rubric.xls',
#    'response': 'hello'},
#   {'cmd': 'x.sum_1_n(3)',
#    'target': 6,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 6},
#   {'cmd': 'x.sum_1_n(100)',
#    'target': 5050,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 5050},
#   {'cmd': 'x.sum_1_n(-10)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': 0},
#   {'cmd': 'x.sum_1_n(0.5)',
#    'target': 0,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 0},
#   {'cmd': 'x.sum_1_n(hello)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n([1, 2, 3])',
#    'target': [1, 3, 6],
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': [1, 3, 6]},
#   {'cmd': 'x.sum_1_n_no_checks(3)',
#    'target': 6,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 6},
#   {'cmd': 'x.sum_1_n_no_checks(100)',
#    'target': 5050,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 5050},
#   {'cmd': 'x.sum_1_n_no_checks(-10)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': 0},
#   {'cmd': 'x.sum_1_n_no_checks(0.5)',
#    'target': 0,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n_no_checks(hello)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n_no_checks([1, 2, 3])',
#    'target': [1, 3, 6],
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': None}],
#  [{'cmd': 'x.say_hello(goodbye)',
#    'target': '',
#    'points': 0.25,
#    'rubric': 'private_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n([-100, 30, 7, 50])',
#    'target': [0, 465, 28, 1275],
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': [0, 465, 28, 1275]},
#   {'cmd': 'x.sum_1_n(1000000)',
#    'target': 500000500000,
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': 500000500000},
#   {'cmd': 'x.sum_1_n_no_checks([-100, 30, 7, 50])',
#    'target': [0, 465, 28, 1275],
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n_no_checks(1000000)',
#    'target': 500000500000,
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': 500000500000}]]

# %%
failed
# Out:
# [[{'cmd': 'x.say_hello()',
#    'target': 'hello',
#    'points': 0.5,
#    'rubric': 'public_rubric.xls',
#    'response': 'hello'},
#   {'cmd': 'x.sum_1_n(3)',
#    'target': 6,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 6},
#   {'cmd': 'x.sum_1_n(100)',
#    'target': 5050,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 5050},
#   {'cmd': 'x.sum_1_n(-10)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': 0},
#   {'cmd': 'x.sum_1_n(0.5)',
#    'target': 0,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 0},
#   {'cmd': 'x.sum_1_n(hello)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n([1, 2, 3])',
#    'target': [1, 3, 6],
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': [1, 3, 6]},
#   {'cmd': 'x.sum_1_n_no_checks(3)',
#    'target': 6,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 6},
#   {'cmd': 'x.sum_1_n_no_checks(100)',
#    'target': 5050,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': 5050},
#   {'cmd': 'x.sum_1_n_no_checks(-10)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': 0},
#   {'cmd': 'x.sum_1_n_no_checks(0.5)',
#    'target': 0,
#    'points': 1.0,
#    'rubric': 'public_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n_no_checks(hello)',
#    'target': 0,
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n_no_checks([1, 2, 3])',
#    'target': [1, 3, 6],
#    'points': 2.0,
#    'rubric': 'public_rubric.xls',
#    'response': None}],
#  [{'cmd': 'x.say_hello(goodbye)',
#    'target': '',
#    'points': 0.25,
#    'rubric': 'private_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n([-100, 30, 7, 50])',
#    'target': [0, 465, 28, 1275],
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': [0, 465, 28, 1275]},
#   {'cmd': 'x.sum_1_n(1000000)',
#    'target': 500000500000,
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': 500000500000},
#   {'cmd': 'x.sum_1_n_no_checks([-100, 30, 7, 50])',
#    'target': [0, 465, 28, 1275],
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': None},
#   {'cmd': 'x.sum_1_n_no_checks(1000000)',
#    'target': 500000500000,
#    'points': 2.0,
#    'rubric': 'private_rubric.xls',
#    'response': 500000500000}]]

# %%
r
# Out:
#              function      input   solution  points
# 0           say_hello        NaN    'hello'     0.5
# 1             sum_1_n          3          6     1.0
# 2             sum_1_n        100       5050     1.0
# 3             sum_1_n        -10          0     2.0
# 4             sum_1_n        0.5          0     1.0
# 5             sum_1_n      hello          0     2.0
# 6             sum_1_n  [1, 2, 3]  [1, 3, 6]     2.0
# 7   sum_1_n_no_checks          3          6     1.0
# 8   sum_1_n_no_checks        100       5050     1.0
# 9   sum_1_n_no_checks        -10          0     2.0
# 10  sum_1_n_no_checks        0.5          0     1.0
# 11  sum_1_n_no_checks      hello          0     2.0
# 12  sum_1_n_no_checks  [1, 2, 3]  [1, 3, 6]     2.0

# %%
submission.sum_1_n(from_str(r.loc[6]['input']))
# Out:
# [1, 3, 6]
